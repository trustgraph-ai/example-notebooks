# %% [markdown]
# Prompts taken from work by Antonio Formato
#
# See: https://github.com/format81/GenAI-STIX2.1-Generator/blob/main/GenAI_Stix2_1_Generator.ipynb
#
# Scrapes a web page, and feeds the data into TrustGraph prompts.
#
# The prompts are configured into TrustGraph's prompt-manager.  The prompt configuration I used is in prompt-configuraiton.txt.  This should replace all of the prompt configuration in docker-compose.yaml.

# %% [markdown]
# # Install

# %%
# !pip install trustgraph-base
# !pip install bs4
# !pip install pandas
# Out:
# Requirement already satisfied: trustgraph-base in ./env/lib64/python3.12/site-packages (0.19.3)
# Requirement already satisfied: pulsar-client in ./env/lib64/python3.12/site-packages (from trustgraph-base) (3.5.0)
# Requirement already satisfied: prometheus-client in ./env/lib64/python3.12/site-packages (from trustgraph-base) (0.21.0)
# Requirement already satisfied: certifi in ./env/lib64/python3.12/site-packages (from pulsar-client->trustgraph-base) (2024.8.30)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: bs4 in ./env/lib64/python3.12/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in ./env/lib64/python3.12/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in ./env/lib64/python3.12/site-packages (from beautifulsoup4->bs4) (2.6)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pandas in ./env/lib64/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in ./env/lib64/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib64/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib64/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./env/lib64/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in ./env/lib64/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# URL to use, same as notebook above
url = "https://cloud.google.com/blog/topics/threat-intelligence/untangling-iran-apt42-operations/"

# %% [markdown]
# # Web-scraper
#
# Just copied from Antonio Formato's notebook

# %%
# Web scraper
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_text(url):
    # Add user-agent to avoid issue when scrapping most website
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"}

    # Send a GET request to the URL
    response = requests.get(url, headers=headers)

    # If the GET request is successful, the status code will be 200
    if response.status_code == 200:
        # Get the content of the response
        page_content = response.content
        # Create a BeautifulSoup object and specify the parser
        soup = BeautifulSoup(page_content, "html.parser")
        # Get the text of the soup object
        text = soup.get_text()
        # Return the text
        return text
    else:
        return "Failed to scrape the website"


text = scrape_text(url)

# %%
print(text[:1000] + "...")
# Out:
# Uncharmed: Untangling Iran's APT42 Operations | Google Cloud BlogJump to ContentCloudBlogContact sales Get started for free CloudBlogSolutions & technologyAI & Machine LearningAPI ManagementApplication DevelopmentApplication ModernizationChrome EnterpriseComputeContainers & KubernetesData AnalyticsDatabasesDevOps & SREMaps & GeospatialSecuritySecurity & IdentityThreat IntelligenceInfrastructureInfrastructure ModernizationNetworkingProductivity & CollaborationSAP on Google CloudStorage & Data TransferSustainabilityEcosystemIT LeadersIndustriesFinancial ServicesHealthcare & Life SciencesManufacturingMedia & EntertainmentPublic SectorRetailSupply ChainTelecommunicationsPartnersStartups & SMBTraining & CertificationsInside Google CloudGoogle Cloud Next & EventsGoogle Maps PlatformGoogle WorkspaceDevelopers & PractitionersTransform with Google CloudContact sales Get started for free Threat IntelligenceUncharmed: Untangling Iran's APT42 OperationsMay 1, 2024Mandiant Written by: Ofir Rozmann,...

# %% [markdown]
# # Initialise API
#
# Assumes TrustGraph is running on same machine as Jupyter notebook.  Also STIX special-purpose prompts need to be created as described above.

# %%
import trustgraph.api as tg

api = tg.Api()

# %%
import json

# %% [markdown]
# ## Extract STIX Domain Objects
#
# Just calls the prompt engine

# %%
sdo = api.prompt(
    "stix-sdo",
    {
        "text": text
    }
)

# %%
stix_sdo = json.dumps(sdo, indent=4)
print(stix_sdo)
# Out:
# [
#     {
#         "type": "intrusion-set",
#         "spec_version": "2.1",
#         "id": "intrusion-set--34c5172b-f793-4a39-942a-928862051178",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "name": "APT42",
#         "description": "APT42, an Iranian state-sponsored cyber espionage actor, is known for its extensive credential harvesting operations and cloud-based intrusions. The group frequently targets Western and Middle Eastern NGOs, media, academia, legal services, and activists. APT42 leverages social engineering, custom malware like NICECURL and TAMECAT, and built-in cloud features to achieve its objectives.",
#         "aliases": [
#             "CALANQUE",
#             "Charming Kitten",
#             "Mint Sandstorm",
#             "Phosphorus",
#             "TA453",
#             "Yellow Garuda",
#             "ITG18"
#         ],
#         "primary_motivation": "espionage",
#         "secondary_motivations": [
#             "collection"
#         ]
#     },
#     {
#         "type": "malware",
#         "spec_version": "2.1",
#         "id": "malware--a641e44f-b5b8-4901-a054-420f278f7442",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "name": "NICECURL",
#         "description": "A backdoor written in VBScript that can download additional modules to be executed, including data mining and arbitrary command execution.",
#         "is_family": "true",
#         "labels": [
#             "backdoor"
#         ]
#     },
#     {
#         "type": "malware",
#         "spec_version": "2.1",
#         "id": "malware--8b275078-520a-4e78-a769-609814f276f8",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "name": "TAMECAT",
#         "description": "A PowerShell toehold that can execute arbitrary PowerShell or C# content.",
#         "is_family": "true",
#         "labels": [
#             "backdoor"
#         ]
#     },
#     {
#         "type": "threat-actor",
#         "spec_version": "2.1",
#         "id": "threat-actor--9a78c377-45f8-4633-9425-558832f712a3",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "name": "IRGC-IO affiliated group",
#         "description": "APT42 is assessed to operate on behalf of the Islamic Revolutionary Guard Corps Intelligence Organization (IRGC-IO).",
#         "labels": [
#             "state-sponsored",
#             "Iranian"
#         ],
#         "roles": [
#             "operator"
#         ]
#     },
#     {
#         "type": "attack-pattern",
#         "spec_version": "2.1",
#         "id": "attack-pattern--f343f35d-512f-4a68-872b-321178a54b3c",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "name": "Credential Harvesting",
#         "description": "APT42 utilizes enhanced social engineering schemes, including posing as journalists and event organizers, to build trust with victims and deliver malicious links or attachments. These lead to credential harvesting pages mimicking legitimate services like Google, Microsoft, and Yahoo.",
#         "external_references": [
#             {
#                 "source_name": "Google Cloud Blog",
#                 "url": "https://cloud.google.com/blog/products/identity-security/uncharmed-untangling-irans-apt42-operations"
#             }
#         ]
#     },
#     {
#         "type": "attack-pattern",
#         "spec_version": "2.1",
#         "id": "attack-pattern--4a3b685c-218f-473d-b24a-8877a5bc3d1e",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "name": "Cloud-Based Intrusions",
#         "description": "After gaining initial access through credential harvesting, APT42 exploits built-in cloud features and open-source tools to exfiltrate data from Microsoft 365 environments, including OneDrive, Outlook, and SharePoint.",
#         "external_references": [
#             {
#                 "source_name": "Google Cloud Blog",
#                 "url": "https://cloud.google.com/blog/products/identity-security/uncharmed-untangling-irans-apt42-operations"
#             }
#         ]
#     }
# ]

# %% [markdown]
# ## STIX Cyber-observable Objects
#
# Just calls the prompt engine

# %%
sco = api.prompt(
    "stix-sco",
    {
        "text": text
    }
)

# %%
stix_sco = json.dumps(sco, indent=4)
print(stix_sco)
# Out:
# [
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--09966076-857b-4726-8008-87e793a92c75",
#         "value": "washinqtonpost.press"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--92c84bca-4c93-4a83-811b-1f8a520958a6",
#         "value": "ksview.top"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--e59930a5-2035-4137-8a21-6f8832133422",
#         "value": "honest-halcyon-fresher.buzz"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--f0848c9a-8025-4a27-8145-502f2a40f252",
#         "value": "sites.google.com"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--8a740a38-080f-4a23-a748-80a8f2a08a74",
#         "value": "n9.cl"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--2389f238-2389-4f23-8238-9f2382389f23",
#         "value": "review.modification-check.online"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--f2094857-f084-48c9-a802-54a278145502",
#         "value": "nterview.site"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--3829ff23-8329-42ff-3832-9ff238329ff2",
#         "value": "admin-stable-right.top"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--4958302f-9348-457f-0849-58302f934857",
#         "value": "shortlinkview.live"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--573920f8-4573-920f-8457-3920f8457392",
#         "value": "panel-view.live"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--0f849583-02f9-3485-7f08-4958302f9348",
#         "value": "reconsider.site"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--85739f20-8457-3920-f845-73920f845739",
#         "value": "last-check-leave.buzz"
#     },
#     {
#         "type": "url",
#         "spec_version": "2.1",
#         "id": "url--f823938f-2393-48ff-2393-8ff23938ff23",
#         "value": "hxxps://email-daemon.online/<university_acronym>365.onmicrosofl.com/accountID=<target_handle>"
#     },
#     {
#         "type": "url",
#         "spec_version": "2.1",
#         "id": "url--2938ff32-938f-4239-38ff-32938ff32938",
#         "value": "hxxps://bitly.org.il/t4m1rpa"
#     },
#     {
#         "type": "url",
#         "spec_version": "2.1",
#         "id": "url--329ff238-329f-4f23-938f-f23938ff2393",
#         "value": "hxxps://bitly.org.il/J03p4y3r"
#     },
#     {
#         "type": "url",
#         "spec_version": "2.1",
#         "id": "url--ff23938f-f239-38ff-2393-8ff23938ff23",
#         "value": "hxxps://youtransfer.live/ICT-2023/J03py3r"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--938ff329-38ff-4329-ff23-8329ff238329",
#         "value": "aspenlnstitute.org"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--238329ff-2383-29ff-2383-29ff238329ff",
#         "value": "drive-file-share.site"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--f238329f-f238-329f-f238-329ff238329f",
#         "value": "prism-west-candy.glitch.me"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--23938ff2-3938-ff23-938f-f23938ff2393",
#         "value": "worried-eastern-salto.glitch.me"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--38ff2393-8ff2-3938-ff23-938ff23938ff",
#         "value": "s3.tebi.io"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--ff23938f-f239-38ff-2393-8ff23938ff24",
#         "value": "tnt200.mywire.org"
#     },
#     {
#         "type": "domain-name",
#         "spec_version": "2.1",
#         "id": "domain-name--29ff2383-29ff-2383-29ff-238329ff2383",
#         "value": "accurate-sprout-porpoise.glitch.me"
#     },
#     {
#         "type": "email-addr",
#         "spec_version": "2.1",
#         "id": "email-addr--49c8b339-865b-4289-8674-8573920f8457",
#         "value": "<victim_org_name>@outlook.com"
#     }
# ]

# %% [markdown]
# # STIX 2.1 Relationship Object
#
# Just calls the prompt engine.  The SDO and SCO data are also passed in.

# %%
sro = api.prompt(
    "stix-sro",
    {
        "text": text,
        "stix_sdo": stix_sdo,
        "stix_sco": stix_sco,
    }
)

# %%
stix_sro = json.dumps(sro, indent=4)
print(stix_sro)
# Out:
# [
#     {
#         "type": "relationship",
#         "spec_version": "2.1",
#         "id": "relationship--38294a77-765b-4633-b525-32f712a39a78",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "relationship_type": "uses",
#         "source_ref": "intrusion-set--34c5172b-f793-4a39-942a-928862051178",
#         "target_ref": "malware--a641e44f-b5b8-4901-a054-420f278f7442"
#     },
#     {
#         "type": "relationship",
#         "spec_version": "2.1",
#         "id": "relationship--92886205-1178-4a39-942a-34c5172bf793",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "relationship_type": "uses",
#         "source_ref": "intrusion-set--34c5172b-f793-4a39-942a-928862051178",
#         "target_ref": "malware--8b275078-520a-4e78-a769-609814f276f8"
#     },
#     {
#         "type": "relationship",
#         "spec_version": "2.1",
#         "id": "relationship--558832f7-12a3-4633-9425-9a78c37745f8",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "relationship_type": "attributed-to",
#         "source_ref": "intrusion-set--34c5172b-f793-4a39-942a-928862051178",
#         "target_ref": "threat-actor--9a78c377-45f8-4633-9425-558832f712a3"
#     },
#     {
#         "type": "relationship",
#         "spec_version": "2.1",
#         "id": "relationship--321178a5-4b3c-4a68-872b-f343f35d512f",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "relationship_type": "uses",
#         "source_ref": "intrusion-set--34c5172b-f793-4a39-942a-928862051178",
#         "target_ref": "attack-pattern--f343f35d-512f-4a68-872b-321178a54b3c"
#     },
#     {
#         "type": "relationship",
#         "spec_version": "2.1",
#         "id": "relationship--8877a5bc-3d1e-473d-b24a-4a3b685c218f",
#         "created": "2024-05-01T00:00:00Z",
#         "modified": "2024-05-01T00:00:00Z",
#         "relationship_type": "uses",
#         "source_ref": "intrusion-set--34c5172b-f793-4a39-942a-928862051178",
#         "target_ref": "attack-pattern--4a3b685c-218f-473d-b24a-8877a5bc3d1e"
#     }
# ]
