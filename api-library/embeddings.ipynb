# %%
import trustgraph.api as tg

# %%
# ID of flow
flow = "default"
base_url = "http://localhost:8088"

# %%
cli = tg.Api(base_url)

# %%
resp = cli.flow().id(flow).embeddings("Write a joke about llamas.")

# %%
for vec in resp:
    print(vec)
# Out:
# [-0.006646334532017787, 0.04116518708225437, -0.010634854689566785, 0.07634271302760413, -0.059259674186063996, -0.037268010010370826, -0.0005511807063625436, -0.060798328845824263, 0.009347924593213977, 0.09902219163569284, 0.014884612223120427, -0.07766565708537333, 0.06221271376716617, -0.01677063233110895, -0.013128051099637722, 0.05613060090812662, 0.024006077891613308, -0.008432687778612348, 0.010137425806018192, 0.026536696955162146, 0.0820613321559467, 0.045377585978101154, 0.044834872924781825, 0.015684051697451233, -0.021425017966497747, 0.04547888837630147, -0.032960992929096745, 0.035737527110451486, -0.05201435121640121, 0.02556157514099736, -0.10717397165408243, 0.00816962195574197, 0.026643223511914452, -0.006869046607332735, -0.06206951031478626, 0.014350831958100782, 0.09350320715602689, 0.10322716067594913, 0.030819249198810305, 0.05373776988553804, 0.05079083791513816, -0.0014951805316021339, 0.050253326876550646, -0.052290215879749656, 0.060696004495943846, -0.101
# ...
