# %% [markdown]
# # Graph visualization using NetworkX
#
# This notebook demonstrates the use of the TrustGraph triple store API to fetch information from the knowledge graph. This information is then visualized using the networkX graph visualisation library.  This notebook was executed against a running TrustGraph loaded with the space shuttle challenger report from NASA located here:
#
# https://ntrs.nasa.gov/citations/19860015255

# %%
# !pip install networkx
# !pip install matplotlib
# Out:
# Requirement already satisfied: networkx in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (3.5)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mark/work/trustgraph.ai/example-notebooks/env/lib64/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import networkx as nx
import matplotlib.pyplot as plt
import trustgraph.api as tg
from trustgraph.api import Uri, Literal

# %%
# ID of flow
flow = "default"
base_url = "http://localhost:8088"

# %%
cli = tg.Api(base_url).flow().id(flow)

# %%
# Utility function, given a label works backward to find the URI of the graph node associated with that label
def get_entity(label):

    resp = cli.triples_query(
        p = Uri("http://www.w3.org/2000/01/rdf-schema#label"),
        o = Literal(label),
        limit = 1
    )

    # Return first row answer
    for row in resp:
        return row.s

    # Or raise exception
    raise RuntimeError("Couldn't resolve entity")

# %%
# Given an entity URI, find the label
def get_label(ent):

    if ent == "http://www.w3.org/2000/01/rdf-schema#label": return "label"
    if ent == "https://schema.org/subjectOf": return "subject of"
    if ent.startswith("https://trustgraph.ai/doc/"): return "source document"
    if ent == "http://www.w3.org/2004/02/skos/core#definition": return "definition"
    if ent == "https://schema.org/keywords": return "keyword"
    if ent == "https://schema.org/description": return "keyword"
    if ent == "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": return "type"
    if ent == "https://schema.org/copyrightNotice": return "(c) notice"
    if ent == "https://schema.org/copyrightHolder": return "(c) held"
    if ent == "https://schema.org/copyrightYear": return "(c) year"

    if not ent.startswith("http"): return ent

    resp = cli.triples_query(
        s = Uri(ent),
        p = Uri("http://www.w3.org/2000/01/rdf-schema#label"),
        limit = 1
    )

    for row in resp:
        return row.o
        
    # If no label, just dump the entity, the URI can be its label
    return ent

# %%
# Given a graph node specified by URI, find related edges which start at that node
def get_related_edges(s, limit=20, follows=1):

    resp = cli.triples_query(
        s = Uri(s),
        limit = limit
    )

    res = [
        [s, row.p, row.o]
        for row in resp
    ]

    if follows > 1:
        seeds = [ r[2] for r in res ]
        for se in seeds:
            if se.startswith("http"):
                res.extend(get_related_edges(se, limit, follows - 1))

    return res

# %%
# Get some useful starting seeds
shuttle = get_entity("Space Shuttle")
tank = get_entity("fuel tank")
oring = get_entity("O-ring")

# %%
# Follow edges start at the seeds above to build a collection of statements
edges = []
edges.extend(get_related_edges(shuttle))
edges.extend(get_related_edges(tank))
edges.extend(get_related_edges(oring))

# %%
edges
# Out:
# [['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/became',
#   'focus of NASAs near-term future'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/can-perform',
#   'perform'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/completed',
#   'four test flights'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/composed-of',
#   'http://trustgraph.ai/e/expendable-external-fuel-tank'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/composed-of',
#   'http://trustgraph.ai/e/orbiter'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/composed-of',
#   'http://trustgraph.ai/e/solid-rocket-boosters'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/designed-to-deliver',
#   '32,000 pounds'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/designed-to-deliver',
#   '65,000 pounds of payload'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/experienced',
#   'http://trustgraph.ai/e/disintegration'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/experienced',
#   'http://trustgraph.ai/e/fire'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/flew',
#   '24 successful missions'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/flew-on',
#   'April 12-14, 1981'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/had',
#   'rapid break-up'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/has',
#   'brakes and tires'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/has',
#   'http://trustgraph.ai/e/cockpit'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/has-elements',
#   'http://trustgraph.ai/e/external-tank'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/has-elements',
#   'http://trustgraph.ai/e/orbiter'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/has-elements',
#   'main engines'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/have',
#   'thrust termination capability'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/hinges-on',
#   'http://trustgraph.ai/e/requirement'],
#  ['http://trustgraph.ai/e/fuel-tank',
#   'http://www.w3.org/2000/01/rdf-schema#label',
#   'fuel tank'],
#  ['http://trustgraph.ai/e/fuel-tank',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'equipment'],
#  ['http://trustgraph.ai/e/fuel-tank',
#   'https://schema.org/subjectOf',
#   'https://trustgraph.ai/doc/challenger-report-vol-1'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/affected-by',
#   'cold temperature'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/attacked-by',
#   'hot gas'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/attempts-to-return-to',
#   'uncompressed shape'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/bulging',
#   'from the groove'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/compressed',
#   'http://trustgraph.ai/e/diameter'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/contacts',
#   'http://trustgraph.ai/e/groove-surfaces'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/contacts',
#   'surfaces'],
#  ['http://trustgraph.ai/e/o-ring', 'http://trustgraph.ai/e/detach', 'seat'],
#  ['http://trustgraph.ai/e/o-ring', 'http://trustgraph.ai/e/did', 'seal'],
#  ['http://trustgraph.ai/e/o-ring', 'http://trustgraph.ai/e/did-not', 'seal'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/did-not-re-establish',
#   'contac'],
#  ['http://trustgraph.ai/e/o-ring', 'http://trustgraph.ai/e/does', 'seal'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/existed-between',
#   'wall'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/experienced',
#   'erosion'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/experiences',
#   'resiliency degradation'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/extrude-into',
#   'http://trustgraph.ai/e/gap'],
#  ['http://trustgraph.ai/e/o-ring', 'http://trustgraph.ai/e/failed-to', 'seal'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/fills',
#   'http://trustgraph.ai/e/groove'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/follows',
#   'opening'],
#  ['http://trustgraph.ai/e/o-ring',
#   'http://trustgraph.ai/e/had',
#   'erod-ed .032 inches']]

# %% [markdown]
# # Visualization
#
# To make networkX happy this information needs to be modeled in a different way.  This information gets converted into various forms which use numeric IDs instead of strings.

# %%
# Produces a list of entities which are sources and objects.  This list does not contain predicates
ents = list(set([e[0] for e in edges] + [e[2] for e in edges]))

# URI to ID mapping in both directions
id2label = { ix: ent for ix, ent in enumerate(ents) }
label2id = { ent: ix for ix, ent in enumerate(ents) }

# ID to human-readable label for nodes
id2name = { ix: get_label(ent) for ix, ent in enumerate(ents) }

# %%
# Edge list, list of (subject, object) pairs
network_e = [(label2id[e[0]], label2id[e[2]]) for e in edges]

# %%
# Mapping from edge to edge label
edge_labels = {
    (label2id[e[0]], label2id[e[2]]): get_label(e[1])
    for e in edges
}

# %%
# Create a directed graph using NetworkX
network = nx.DiGraph()

# Add edges
network.add_edges_from(network_e)

# Visualize the directed graph using a spring layout - this computes positions for all nodes
pos = nx.spring_layout(network)

# %%
# Get drawing.  Nice big image frame
plt.figure(figsize=(16,10))

# Draw nodes, edges, labels on nodes and labels on edges
nx.draw_networkx_nodes(network, pos, node_shape='o', node_color='red', node_size=50)
nx.draw_networkx_edges(network, pos, edge_color='darkgray')
nx.draw_networkx_labels(network, pos, labels=id2name)
nx.draw_networkx_edge_labels(network, pos, edge_labels=edge_labels)

# Show the pic
plt.show()
