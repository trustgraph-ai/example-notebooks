# %% [markdown]
# # Graph visualization using NetworkX
#
# This notebook demonstrates the use of the TrustGraph triple store API to fetch information from the knowledge graph. This information is then visualized using the networkX graph visualisation library.  This notebook was executed against a running TrustGraph loaded with the space shuttle challenger report from NASA located here:
#
# https://ntrs.nasa.gov/citations/19860015255

# %%
# !pip install networkx
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: networkx in /home/mark/.local/lib/python3.13/site-packages (3.4.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /usr/lib64/python3.13/site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/lib64/python3.13/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib64/python3.13/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib64/python3.13/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /usr/lib64/python3.13/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.13/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.13/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3.13/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.13/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import trustgraph.api as tg

# %%
cli = tg.Api()

# %%
# Utility function, given a label works backward to find the URI of the graph node associated with that label
def get_entity(label):

    resp = cli.triples_query(
        p = "http://www.w3.org/2000/01/rdf-schema#label",
        o = label,
        limit = 1
    )

    # Return first row answer
    for row in resp:
        return row.s

    # Or raise exception
    raise RuntimeError("Couldn't resolve entity")

# %%
# Given an entity URI, find the label
def get_label(ent):

    if ent == "http://www.w3.org/2000/01/rdf-schema#label": return "label"
    if ent == "https://schema.org/subjectOf": return "subject of"
    if ent.startswith("https://trustgraph.ai/doc/"): return "source document"
    if ent == "http://www.w3.org/2004/02/skos/core#definition": return "definition"
    if ent == "https://schema.org/keywords": return "keyword"
    if ent == "https://schema.org/description": return "keyword"
    if ent == "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": return "type"
    if ent == "https://schema.org/copyrightNotice": return "(c) notice"
    if ent == "https://schema.org/copyrightHolder": return "(c) held"
    if ent == "https://schema.org/copyrightYear": return "(c) year"

    if not ent.startswith("http"): return ent

    resp = cli.triples_query(
        s = ent,
        p = "http://www.w3.org/2000/01/rdf-schema#label",
        limit = 1
    )

    for row in resp:
        return row.o
        
    # If no label, just dump the entity, the URI can be its label
    return ent

# %%
# Given a graph node specified by URI, find related edges which start at that node
def get_related_edges(s, limit=20, follows=1):

    resp = cli.triples_query(
        s = s,
        limit = limit
    )

    res = [
        [s, row.p, row.o]
        for row in resp
    ]

    if follows > 1:
        seeds = [ r[2] for r in res ]
        for se in seeds:
            if se.startswith("http"):
                res.extend(get_related_edges(se, limit, follows - 1))

    return res

# %%
# Get some useful starting seeds
shuttle = get_entity("Space Shuttle")
booster = get_entity("Solid Rocket Booster")
tank = get_entity("external fuel tank")
thruster = get_entity("thruster")
#explosion = get_entity("explosion")
#oring = get_entity("o-ring")

# %%
# Follow edges start at the seeds above to build a collection of statements
edges = []
edges.extend(get_related_edges(shuttle))
edges.extend(get_related_edges(booster))
edges.extend(get_related_edges(tank))
edges.extend(get_related_edges(thruster))

# %%
edges
# Out:
# [['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/became-the-focus-of',
#   'http://trustgraph.ai/e/nasa%27s-near-term-future'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/certified-for',
#   'http://trustgraph.ai/e/operational-flights'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/composed-of',
#   'http://trustgraph.ai/e/orbiter%2C-external-fuel-tank%2C-and-two-solid-rocket-boosters'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/composed-of',
#   'http://trustgraph.ai/e/orbiter%2C-external-fuel-tank%2C-two-solid-rocket-boosters'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/deliver-payload-to',
#   'http://trustgraph.ai/e/easterly-low-earth-orbit'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/deliver-payload-to',
#   'http://trustgraph.ai/e/polar-orbit'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/designed-to-deliver',
#   '32,000 pounds'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/designed-to-deliver',
#   '32,000 pounds to polar orbit'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/designed-to-deliver',
#   '65,000 pounds of payload'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/designed-to-deliver',
#   'http://trustgraph.ai/e/payload'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/flew',
#   '24 successful missions'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/flew-on',
#   'April 12-14, 1981'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/have',
#   'thrust termination capability'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/hinges-on',
#   'http://trustgraph.ai/e/requirement'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/land',
#   'water'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/lifted-to-orbit-by',
#   'http://trustgraph.ai/e/thrust-from-two-solid-rockets-and-three-main-engines'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/lifted-to-orbit-by',
#   'thrust from two solid rockets and three main engines'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/principal-component-of',
#   'http://trustgraph.ai/e/national-space-transportation-system'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/ready-for',
#   'an orbital flight test program'],
#  ['http://trustgraph.ai/e/space-shuttle',
#   'http://trustgraph.ai/e/remains',
#   'a totally new system with little or no history'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://trustgraph.ai/e/comprises',
#   'http://trustgraph.ai/e/seven-subsystems'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://trustgraph.ai/e/comprises',
#   'http://trustgraph.ai/e/structures%2C-thrust-vector-control%2C-range-safety%2C-separation%2C-electrical-and-instrumentation%2C-recovery%2C-and-the-solid-rocket-motor'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://trustgraph.ai/e/comprises',
#   'seven subsystems'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://trustgraph.ai/e/comprises',
#   'structures, thrust vector control, range safety, separation, electrical and instrumentation, recovery, and the Solid Rocket Motor'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://trustgraph.ai/e/have',
#   'http://trustgraph.ai/e/11-separate-case-components'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://trustgraph.ai/e/ignition',
#   '0 sec'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://trustgraph.ai/e/is-made-up-of',
#   'http://trustgraph.ai/e/several-subassemblies'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://trustgraph.ai/e/were-not-identified-with',
#   'problems'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2000/01/rdf-schema#label',
#   'Solid Rocket Booster'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of a rocket'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of a rocket that provides thrust during launch.'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of a rocket that provides thrust during the initial phase of launch.'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of a rocket that provides thrust through the burning of solid propellant.'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of a rocket that uses solid propellant'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of a rocket that uses solid propellant to generate thrust.'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of a rocket used to provide thrust during the initial stages of launch.'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of the Space Shuttle'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of the Space Shuttle made up of subassemblies including the nose cone, Solid Rocket Motor, and nozzle assembly.  The Solid Rocket Motors are made of 11 cylindrical steel sections joined by tang-and-clevis joints and steel pins.  These sections are partly assembled into four casting segments at the factory and further assembled at Kennedy Space Center.'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of the Space Shuttle made up of subassemblies including the nose cone, Solid Rocket Motor, and nozzle assembly.  The Solid Rocket Motors are made of 11 steel sections joined by tang-and-clevis joints and steel pins.  These sections are partly assembled into four casting segments at the factory and further assembled at Kennedy Space Center.'],
#  ['http://trustgraph.ai/e/solid-rocket-booster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A component of the Space Shuttle responsible for providing thrust during launch.'],
#  ['http://trustgraph.ai/e/external-fuel-tank',
#   'http://trustgraph.ai/e/carrying',
#   "liquid propellants for the Orbiter's engines"],
#  ['http://trustgraph.ai/e/external-fuel-tank',
#   'http://www.w3.org/2000/01/rdf-schema#label',
#   'External fuel tank'],
#  ['http://trustgraph.ai/e/external-fuel-tank',
#   'http://www.w3.org/2000/01/rdf-schema#label',
#   'external fuel tank'],
#  ['http://trustgraph.ai/e/external-fuel-tank',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   "an expendable part of the Space Shuttle carrying liquid propellants for the Orbiter's engines"],
#  ['http://trustgraph.ai/e/external-fuel-tank',
#   'https://schema.org/subjectOf',
#   'https://trustgraph.ai/doc/72ef3374-af7a-40c4-8c7b-45050aef5b90'],
#  ['http://trustgraph.ai/e/thruster',
#   'http://www.w3.org/2000/01/rdf-schema#label',
#   'thruster'],
#  ['http://trustgraph.ai/e/thruster',
#   'http://www.w3.org/2004/02/skos/core#definition',
#   'A device that produces thrust'],
#  ['http://trustgraph.ai/e/thruster',
#   'https://schema.org/subjectOf',
#   'https://trustgraph.ai/doc/72ef3374-af7a-40c4-8c7b-45050aef5b90']]

# %% [markdown]
# # Visualization
#
# To make networkX happy this information needs to be modeled in a different way.  This information gets converted into various forms which use numeric IDs instead of strings.

# %%
# Produces a list of entities which are sources and objects.  This list does not contain predicates
ents = list(set([e[0] for e in edges] + [e[2] for e in edges]))

# URI to ID mapping in both directions
id2label = { ix: ent for ix, ent in enumerate(ents) }
label2id = { ent: ix for ix, ent in enumerate(ents) }

# ID to human-readable label for nodes
id2name = { ix: get_label(ent) for ix, ent in enumerate(ents) }

# %%
# Edge list, list of (subject, object) pairs
network_e = [(label2id[e[0]], label2id[e[2]]) for e in edges]

# %%
# Mapping from edge to edge label
edge_labels = {
    (label2id[e[0]], label2id[e[2]]): get_label(e[1])
    for e in edges
}

# %%
# Create a directed graph using NetworkX
network = nx.DiGraph()

# Add edges
network.add_edges_from(network_e)

# Visualize the directed graph using a spring layout - this computes positions for all nodes
pos = nx.spring_layout(network)

# %%
# Get drawing.  Nice big image frame
plt.figure(figsize=(16,10))

# Draw nodes, edges, labels on nodes and labels on edges
nx.draw_networkx_nodes(network, pos, node_shape='o', node_color='red', node_size=50)
nx.draw_networkx_edges(network, pos, edge_color='darkgray')
nx.draw_networkx_labels(network, pos, labels=id2name)
nx.draw_networkx_edge_labels(network, pos, edge_labels=edge_labels)

# Show the pic
plt.show()
